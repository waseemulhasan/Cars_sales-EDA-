# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
from subprocess import check_output

# %% [markdown]
# .Loading Dataset

# %%
Cars_data= pd.read_csv("C:\waseem\coruse_notes\Car_Sales1.csv")

# %%
Cars_data.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
CarSales_Data_copy=Cars_data.copy()

# %%
CarSales_Data_copy.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
Cars_data.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
Cars_data.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %% [markdown]
# .Data Profiling

# %%
Cars_data.shape  ## How many rows & columns
# Out:
# (9576, 10)

# %%
Cars_data.columns ## Name of the column
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
Cars_data.describe(include='all')
# Out:
#                car          price   body      mileage         engV engType  \
# count         9576    9576.000000   9576  9576.000000  9142.000000    9576
# unique          87            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   15633.317316    NaN   138.862364     2.646344     NaN
# std            NaN   24106.523436    NaN    98.629754     5.927699     NaN
# min            NaN       0.000000    NaN     0.000000     0.100000     NaN
# 25%            NaN    4999.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9200.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   16700.000000    NaN   194.000000     2.500000     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %%
Cars_data.sort_values(by=['price'],ascending= False).head(10)
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 7621        Bentley  547800.0      sedan        0  6.75  Petrol          yes
# 7914        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 1611        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 4134        Bentley  449999.0  crossover        0  6.00  Petrol          yes
# 4325  Mercedes-Benz  300000.0      sedan       68  6.00  Petrol          yes
# 5849  Mercedes-Benz  300000.0      other       37  5.00  Petrol          yes
# 1891  Mercedes-Benz  295000.0      sedan       29  6.00  Petrol          yes
# 2165  Mercedes-Benz  295000.0      sedan       29  6.00  Petrol          yes
# 8205     Land Rover  285000.0  crossover        0  5.00  Petrol          yes
# 1478        Bentley  259000.0      sedan        0  6.00  Petrol          yes
#
#       year        model drive
# 7621  2016     Mulsanne  rear
# 7914  2016     Bentayga  full
# ...

# %%
Cars_data.sort_values(by=['price'],ascending= False).tail(10)
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 6665         Toyota    0.0      sedan       24  2.50  Petrol          yes
# 160   Mercedes-Benz    0.0  crossover        0  3.00  Diesel          yes
# 2069     Land Rover    0.0  crossover        1  4.40  Diesel          yes
# 7801     Volkswagen    0.0        van      123  1.20  Petrol          yes
# 2074            BMW    0.0  crossover        0  3.00  Diesel          yes
# 70    Mercedes-Benz    0.0  crossover        0  3.00  Diesel          yes
# 158      Land Rover    0.0  crossover       45  3.00  Petrol          yes
# 4786  Mercedes-Benz    0.0  crossover       27  3.00  Diesel          yes
# 4784    Rolls-Royce    0.0      sedan       22  6.75   Other          yes
# 215   Mercedes-Benz    0.0      sedan       62  3.00  Diesel          yes
#
#       year              model  drive
# 6665  2015              Camry  front
# 160   2016            GLS 350   full
# 2069  2016        Range Rover   full
# ...

# %%
Cars_data.groupby('car')['price'].count().sort_values(ascending=False)   ## Grouping in between cars & prices
# Out:
# car
# Volkswagen       936
# Mercedes-Benz    921
# BMW              694
# Toyota           541
# VAZ              489
#                 ...
# Other-Retro        1
# Lamborghini        1
# Mercury            1
# Maserati           1
# ZX                 1
# Name: price, Length: 87, dtype: int64

# %%
Cars_data['car'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Volkswagen       936
# Mercedes-Benz    921
# BMW              694
# Toyota           541
# VAZ              489
# Renault          469
# Audi             457
# Opel             400
# Nissan           368
# Skoda            368
# Name: car, dtype: int64

# %%
Cars_data['car'].value_counts().sort_values(ascending=False).tail(10)
# Out:
# SMA         1
# Hafei       1
# Fisker      1
# Changan     1
# Barkas      1
# Huanghai    1
# Wartburg    1
# FAW         1
# Aro         1
# Buick       1
# Name: car, dtype: int64

# %%
Cars_data.corr()
# Out:
#             price   mileage      engV      year
# price    1.000000 -0.312415  0.051070  0.370379
# mileage -0.312415  1.000000  0.047070 -0.495599
# engV     0.051070  0.047070  1.000000 -0.042251
# year     0.370379 -0.495599 -0.042251  1.000000

# %%
import seaborn as sns                                              # Provides a high level interface for drawing attractive and informative statistical graphics
sns.set()
plt.subplots(figsize=(5,5))
sns.heatmap(Cars_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
Cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
import pandas_profiling
# Out:
# C:\Users\WASEEM\AppData\Local\Temp\ipykernel_3656\3938355598.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
profile = pandas_profiling.ProfileReport(Cars_data)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-06-13 07:06:26.008835&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file(output_file="CarSales_before_preprocessing.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Preprocessing
#
#  .Dealing with duplicate rows
#  .Find number of duplicate rows in the dataset.
#  .Print the duplicate entries and analyze.
#  .Drop the duplicate entries from the dataset.

# %%
Cars_data.duplicated().sum()
# Out:
# 113

# %%
Cars_data.loc[Cars_data.duplicated(), :]
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 18           Nissan   16600.0  crossover       83   2.0  Petrol          yes
# 42    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# 70    Mercedes-Benz       0.0  crossover        0   3.0  Diesel          yes
# 86           Toyota  103999.0  crossover        0   4.5  Diesel          yes
# 98    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# ...             ...       ...        ...      ...   ...     ...          ...
# 9156     Volkswagen   15700.0      sedan      110   1.8  Petrol          yes
# 9163  Mercedes-Benz   20500.0      sedan      222   5.5  Petrol          yes
# 9164            VAZ    3900.0      hatch      121   1.4  Petrol          yes
# 9169        Hyundai   12900.0  crossover       49   2.7  Petrol          yes
# 9477            BMW   77777.0      sedan        8   4.4  Petrol          yes
#
#       year             model  drive
# ...

# %%
CarSales_Data_copy.drop_duplicates(inplace=True)  ##Droping duplicate values

# %%
CarSales_Data_copy.loc[Cars_data.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [car, price, body, mileage, engV, engType, registration, year, model, drive]
# Index: []

# %%
CarSales_Data_copy.shape
# Out:
# (9463, 10)

# %%
b=CarSales_Data_copy['drive'].mode()  ##replacing drive attribute with mode
b
# Out:
# 0    front
# Name: drive, dtype: object

# %%
CarSales_Data_copy['drive']=CarSales_Data_copy['drive'].fillna('front') ##Filling drive null values with front

# %%
CarSales_Data_copy.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive             0
# dtype: int64

# %%
CarSales_Data_copy['engV'] = CarSales_Data_copy.groupby(['car', 'body'])['engV'].transform(lambda x: x.fillna(x.median()))

# %%
CarSales_Data_copy.isnull().sum()
# Out:
# car              0
# price            0
# body             0
# mileage          0
# engV            10
# engType          0
# registration     0
# year             0
# model            0
# drive            0
# dtype: int64

# %% [markdown]
# 424 missing values of engV has been replaced however, still 10 entries are left as missing. Let's see the missing value data.

# %%
CarSales_Data_copy[CarSales_Data_copy.engV.isnull()]
# Out:
#           car     price       body  mileage  engV engType registration  year  \
# 319     Tesla   58000.0      hatch       52   NaN   Other          yes  2013
# 1437    Tesla  178500.0  crossover        0   NaN   Other          yes  2016
# 2486    Tesla  185000.0  crossover        1   NaN   Other          yes  2016
# 5084      GAZ       0.0  crossover        1   NaN  Petrol          yes  1963
# 6773      UAZ    3000.0      other        1   NaN   Other          yes  1985
# 8569    Tesla  176900.0  crossover        0   NaN   Other          yes  2016
# 8824   Fisker       0.0      other      100   NaN   Other          yes  2001
# 8905  Changan    6028.0  crossover      101   NaN   Other          yes  2005
# 9360   Barkas    5500.0        van       80   NaN  Petrol          yes  2015
# 9566      UAZ     850.0        van      255   NaN   Other          yes  1981
#
#         model  drive
# 319   Model S  front
# 1437  Model X   full
# 2486  Model X   full
# 5084       69   full
# ...

# %% [markdown]
# Replacing NaN values of drive with most common values of drive from Car and body group.

# %%
def f(x):
    if x.count()<=0:
        return np.nan
    return x.value_counts().index[0]

# %%
CarSales_Data_copy['drive'] = CarSales_Data_copy['drive'].fillna(CarSales_Data_copy.groupby(['car','body'])['drive'].transform(f))
#CarSales_Data[CarSales_Data.drive.isnull()]

# %%
CarSales_Data_copy[CarSales_Data_copy.drive.isnull()] ## Checking null values in Drive column
# Out:
# Empty DataFrame
# Columns: [car, price, body, mileage, engV, engType, registration, year, model, drive]
# Index: []

# %%
CarSales_Data_copy.dropna(subset=['engV'],inplace=True) ## Droping NaN values form engV.

# %%
CarSales_Data_copy.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            0
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %%
 CarSales_Data_copy = CarSales_Data_copy.drop(CarSales_Data_copy[CarSales_Data_copy.price <= 0 ].index)

# %%
CarSales_Data_copy.price[CarSales_Data_copy.price==0].count()  ##Dropping entries with price <= 0 .
# Out:
# 0

# %%
b = CarSales_Data_copy["mileage"].median()
CarSales_Data_copy["mileage"]=CarSales_Data_copy["mileage"].replace(0,b)

# %%
CarSales_Data_copy[CarSales_Data_copy.mileage == 0]
# Out:
# Empty DataFrame
# Columns: [car, price, body, mileage, engV, engType, registration, year, model, drive]
# Index: []

# %%
profile_cleaned = pandas_profiling.ProfileReport(CarSales_Data_copy)
profile_cleaned.to_file(output_file="CarSales_post_preprocessing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# .Which type of sold maximum

# %%
sns.countplot(x='body', data=CarSales_Data_copy)
plt.title('Count plot for car variants.')
# Out:
# Text(0.5, 1.0, 'Count plot for car variants.')

# %% [markdown]
# .Correlation between price & mileage

# %%
sns.regplot(x= 'mileage',y = 'price',data = CarSales_Data_copy)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
CarSales_Data_copy['registration'].value_counts() ## How many car register or not register.
# Out:
# yes    8661
# no      554
# Name: registration, dtype: int64

# %%
sns.countplot('registration',data=CarSales_Data_copy)
plt.title('Car Registration status')
# Out:
# C:\Users\WASEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Car Registration status')

# %% [markdown]
# .Price distribution between registered and non-registered cars

# %%
CarSales_Data_copy.groupby(['registration','body'])['price'].mean()
# Out:
# registration  body
# no            crossover     7951.310345
#               hatch         2563.750000
#               other         3936.687500
#               sedan         3938.627049
#               vagon         3124.428571
#               van           3488.457143
# yes           crossover    30597.282810
#               hatch         8723.459297
#               other        20329.349533
#               sedan        12826.420380
#               vagon        10279.830563
#               van          10970.113397
# Name: price, dtype: float64

# %%
sns.boxplot(x='registration',y='price',data = CarSales_Data_copy)
# Out:
# <AxesSubplot:xlabel='registration', ylabel='price'>

# %% [markdown]
# .Majority of the cars are registered and the price of those cars are below 300000. Non-registered cars are cheaper in cost.

# %%
sns.displot(CarSales_Data_copy, x="registration", y='price')

# %%
plt = CarSales_Data_copy[['price', 'registration']].groupby('registration').price.mean().plot(kind='bar')
plt
# Out:
# <AxesSubplot:xlabel='registration'>

# %% [markdown]
# What is the car price distribution based on Engine Value?

# %% [markdown]
# #Except few outliers, it is clearly observed that the range of car price is between 0 to 150000 having
# the range of engine value between 0 to 6.

# %%
sns.regplot(x='engV',y='price', data=CarSales_Data_copy)
# Out:
# <AxesSubplot:xlabel='engV', ylabel='price'>

# %%
sns.scatterplot( x= 'engV',y= 'price',data=CarSales_Data_copy,hue='body')
# Out:
# <AxesSubplot:xlabel='engV', ylabel='price'>

# %% [markdown]
# .Which engine type of cars users preferred maximum?

# %%
CarSales_Data_copy.groupby('engType')['price'].count().sort_values(ascending=False)
##Petrol cars are more preferred and followed by Diesel, Gas and others
# Out:
# engType
# Petrol    4259
# Diesel    2821
# Gas       1692
# Other      443
# Name: price, dtype: int64

# %%
sns.countplot(CarSales_Data_copy['engType'])
# Out:
# C:\Users\WASEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='engType', ylabel='count'>

# %% [markdown]
# .Establish coorelation between all the features using heatmap

# %%
corr_car_sale_data=CarSales_Data_copy.corr()
corr_car_sale_data
# Out:
#             price   mileage      engV      year
# price    1.000000 -0.256693  0.051242  0.391745
# mileage -0.256693  1.000000  0.055425 -0.451794
# engV     0.051242  0.055425  1.000000 -0.047734
# year     0.391745 -0.451794 -0.047734  1.000000

# %%
##plt.subplots(figsize=(10,10))
sns.heatmap(corr_car_sale_data,vmax = 0.8 , linewidth = 0.01 ,square = True,cmap = 'YlGnBu',linecolor = 'black')
plt.title('Correlation between features')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3656\3043163530.py in <module>
#       1 ##plt.subplots(figsize=(10,10))
#       2 sns.heatmap(corr_car_sale_data,vmax = 0.8 , linewidth = 0.01 ,square = True,cmap = 'YlGnBu',linecolor = 'black')
# ----> 3 plt.title('Correlation between features')
#
# TypeError: 'Text' object is not callable

# %% [markdown]
# .Distribution of price.

# %%
sns.distplot(CarSales_Data_copy['price'],color = 'b')
plt.title("Price Distribution")
plt.show()
# Out:
# C:\Users\WASEEM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3656\4036444417.py in <module>
#       1 sns.distplot(CarSales_Data_copy['price'],color = 'b')
# ----> 2 plt.title("Price Distribution")
#       3 plt.show()
#
# TypeError: 'Text' object is not callable

# %%
sns.displot(CarSales_Data_copy['price'],color='g', kde=False)

# %% [markdown]
# Conclusion:
#
# Sedan cars sold maximum.
#
# Price is increasing as the engine value is increasing.
#
# The price and mileage goes down as engine values decreasing.
